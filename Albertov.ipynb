# %%
import pandas as pd
data = pd.read_csv('data/processed/albertov.csv')
lnColors = {"7": "w", "18": "g", "24": "b", "17": "w", "73": "w", "90": "w", "4": "w", "3":"w", "14":"w"}
dataColors = []
for ln in data['lnno']:
     dataColors.append(lnColors[str(ln)])

# %%
gcf().set_size_inches(80,6)
plt.scatter(data['time'],data['day'],s=5, c=dataColors, lw=0,alpha=1)

# %%
data['time']
# Out:
# 0     14276
# 1     14689
# 2     15443
# 3     15914
# 4     16621
# 5     17130
# 6     18055
# 7     18084
# 8     18105
# 9     18163
# 10    18677
# 11    19270
# 12    19321
# 13    19576
# 14    19655
# ...
# 308    83112
# 309    83297
# 310    83713
# 311    84132
# 312    84311
# 313    84511
# 314    84912
# 315    85324
# 316    85527
# 317    85613
# 318    86098
# 319      108
# 320      387
# 321      326
# 322      974
# Name: time, Length: 323, dtype: int64
